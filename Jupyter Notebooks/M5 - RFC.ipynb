# %% [markdown]
# # RANDOM FOREST ALGORITHEM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('INTRUSION.csv')
df.head(60)
# Out:
#     duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0          0          icmp       20     2        491          0     0
# 1          0           udp       45     2        146          0     0
# 2          0          icmp       50     4          0          0     0
# 3          0          icmp       25     2        232       8153     0
# 4          0          icmp       25     2        199        420     0
# 5          0          icmp       50     1          0          0     0
# 6          0          icmp       50     4          0          0     0
# 7          0          icmp       50     4          0          0     0
# 8          0          icmp       52     4          0          0     0
# 9          0          icmp       50     4          0          0     0
# 10         0          icmp       50     1          0          0     0
# 11         0          icmp       50     4          0          0     0
# 12         0          icmp       25     2        287       2251     0
# 13         0          icmp       20     2        334          0     0
# 14         0          icmp       37     4          0          0     0
# 15         0          icmp       39     4          0          0     0
# 16         0          icmp       25     2        300      13788     0
# 17         0           tcp       15     2         18          0     0
# 18         0          icmp       25     2        233        616     0
# 19         0          icmp       25     2        343       1178     0
# 20         0          icmp       36     4          0          0     0
# 21         0          icmp       50     4          0          0     0
# 22         0          icmp       25     2        253      11905     0
# 23      5607           udp       45     2        147        105     0
# 24         0          icmp       36     4          0          0     0
# 25       507          icmp       61     2        437      14421     0
# 26         0          icmp       50     4          0          0     0
# 27         0          icmp       25     2        227       6588     0
# 28         0          icmp       25     2        215      10499     0
# 29         0          icmp       25     2        241       1400     0
# 30         0           tcp       15     2          8          0     0
# 31         0          icmp       19     4          0          0     0
# 32         0          icmp       25     2        303        555     0
# 33         0          icmp       50     1          0          0     0
# 34         0           udp       12     2         45         45     0
# 35         1           udp       50     2        105        147     0
# 36         0           udp       12     2         43         43     0
# 37         0          icmp       59     4          0          0     0
# 38         0          icmp       25     2        324       2302     0
# 39         0          icmp       67     4          0          0     0
# 40         0          icmp       20     4          0          0     0
# 41         0          icmp        3     4          0          0     0
# 42         2          icmp       55     2       1591        372     0
# 43      9052           udp       45     2        146        105     0
# 44         0          icmp       25     2        290       3006     0
# 45         0          icmp        8     4          0          0     0
# 46         0           udp       50     2         28          0     0
# 47         0          icmp       25     2        255        861     0
# 48         0          icmp       20     2        334          0     0
# 49         0          icmp       20     4          0          0     0
# 50         0          icmp       25     2        302        498     0
# 51         0          icmp       50     1          0          0     0
# 52         0           udp       50     2         28          0     0
# 53         0          icmp       25     2        220       1398     0
# 54         0           udp       12     2         43         69     0
# 55         0           udp       12     2         44        133     0
# 56         0           tcp       15     2          8          0     0
# 57         0          icmp       67     4          0          0     0
# 58         0          icmp       19     4          0          0     0
# 59         0           udp       12     2         43         43     0
#
#     wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                0       0    0  ...                  25
# 1                0       0    0  ...                   1
# 2                0       0    0  ...                  26
# 3                0       0    0  ...                 255
# 4                0       0    0  ...                 255
# 5                0       0    0  ...                  19
# 6                0       0    0  ...                   9
# 7                0       0    0  ...                  15
# 8                0       0    0  ...                  23
# 9                0       0    0  ...                  13
# 10               0       0    0  ...                  12
# 11               0       0    0  ...                  13
# 12               0       0    0  ...                 219
# 13               0       0    0  ...                  20
# 14               0       0    0  ...                   1
# 15               0       0    0  ...                   2
# 16               0       0    0  ...                 255
# 17               0       0    0  ...                  16
# 18               0       0    0  ...                 255
# 19               0       0    0  ...                 255
# 20               0       0    0  ...                  23
# 21               0       0    0  ...                  17
# 22               0       0    0  ...                 255
# 23               0       0    0  ...                   1
# 24               0       0    0  ...                   2
# 25               0       0    0  ...                  25
# 26               0       0    0  ...                  13
# 27               0       0    0  ...                 255
# 28               0       0    0  ...                 255
# 29               0       0    0  ...                 255
# 30               0       0    0  ...                  53
# 31               0       0    0  ...                  59
# 32               0       0    0  ...                 255
# 33               0       0    0  ...                   1
# 34               0       0    0  ...                 250
# 35               0       0    0  ...                   5
# 36               0       0    0  ...                 255
# 37               0       0    0  ...                  17
# 38               0       0    0  ...                 255
# 39               0       0    0  ...                  13
# 40               0       0    0  ...                  63
# 41               0       0    0  ...                   9
# 42               0       0    0  ...                 147
# 43               0       0    0  ...                   2
# 44               0       0    0  ...                 255
# 45               0       0    0  ...                  11
# 46               3       0    0  ...                  80
# 47               0       0    0  ...                 255
# 48               0       0    0  ...                  38
# 49               0       0    0  ...                   5
# 50               0       0    0  ...                 255
# 51               0       0    0  ...                   4
# 52               3       0    0  ...                   2
# 53               0       0    0  ...                 255
# 54               0       0    0  ...                 245
# 55               0       0    0  ...                 212
# 56               0       0    0  ...                  46
# 57               0       0    0  ...                  11
# 58               0       0    0  ...                  59
# 59               0       0    0  ...                 255
#
#     dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                     0.17                    0.03
# 1                     0.00                    0.60
# 2                     0.10                    0.05
# 3                     1.00                    0.00
# 4                     1.00                    0.00
# 5                     0.07                    0.07
# 6                     0.04                    0.05
# 7                     0.06                    0.07
# 8                     0.09                    0.05
# 9                     0.05                    0.06
# 10                    0.05                    0.07
# 11                    0.05                    0.07
# 12                    1.00                    0.00
# 13                    1.00                    0.00
# 14                    0.00                    0.07
# 15                    0.01                    0.06
# 16                    1.00                    0.00
# 17                    1.00                    0.00
# 18                    1.00                    0.00
# 19                    1.00                    0.00
# 20                    0.09                    0.05
# 21                    0.07                    0.06
# 22                    1.00                    0.00
# 23                    0.00                    0.85
# 24                    0.01                    0.06
# 25                    0.10                    0.05
# 26                    0.05                    0.07
# 27                    1.00                    0.00
# 28                    1.00                    0.00
# 29                    1.00                    0.00
# 30                    1.00                    0.00
# 31                    0.23                    0.04
# 32                    1.00                    0.00
# 33                    0.00                    0.31
# 34                    0.98                    0.01
# 35                    0.12                    0.05
# 36                    1.00                    0.00
# 37                    0.07                    0.07
# 38                    1.00                    0.00
# 39                    0.05                    0.07
# 40                    0.25                    0.02
# 41                    0.04                    0.07
# 42                    0.81                    0.02
# 43                    0.01                    0.66
# 44                    1.00                    0.00
# 45                    0.04                    0.07
# 46                    0.31                    0.02
# 47                    1.00                    0.00
# 48                    1.00                    0.00
# 49                    0.02                    0.07
# 50                    1.00                    0.00
# 51                    0.02                    0.08
# 52                    0.01                    0.02
# 53                    1.00                    0.00
# 54                    0.96                    0.01
# 55                    0.88                    0.02
# 56                    1.00                    0.00
# 57                    0.04                    0.07
# 58                    0.23                    0.04
# 59                    1.00                    0.00
#
#     dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0
# 29                  0.00                      0.00                  0.00
# 30                  0.00                      0.00                  0.00
# 31                  1.00                      1.00                  0.00
# 32                  0.00                      0.00                  0.00
# 33                  0.00                      0.00                  0.29
# 34                  0.00                      0.00                  0.00
# 35                  0.00                      0.00                  0.00
# 36                  0.00                      0.00                  0.00
# 37                  1.00                      1.00                  0.00
# 38                  0.00                      0.00                  0.00
# 39                  1.00                      1.00                  0.00
# 40                  1.00                      1.00                  0.00
# 41                  1.00                      1.00                  0.00
# 42                  0.00                      0.00                  0.00
# 43                  0.00                      0.00                  0.00
# 44                  0.00                      0.00                  0.00
# 45                  1.00                      1.00                  0.00
# 46                  0.00                      0.00                  0.00
# 47                  0.00                      0.00                  0.00
# 48                  0.00                      0.00                  0.00
# 49                  1.00                      1.00                  0.00
# 50                  0.00                      0.00                  0.00
# 51                  0.00                      0.00                  1.00
# 52                  0.00                      0.00                  0.77
# 53                  0.00                      0.00                  0.00
# 54                  0.00                      0.00                  0.00
# 55                  0.00                      0.00                  0.08
# 56                  0.00                      0.00                  0.00
# 57                  1.00                      1.00                  0.00
# 58                  1.00                      1.00                  0.00
# 59                  0.00                      0.00                  0.00
#
#     dst_host_srv_rerror_rate  xAttack
# 0                       0.00   normal
# 1                       0.00   normal
# 2                       0.00      dos
# 3                       0.01   normal
# 4                       0.00   normal
# 5                       1.00      dos
# 6                       0.00      dos
# 7                       0.00      dos
# 8                       0.00      dos
# 9                       0.00      dos
# 10                      1.00      dos
# 11                      0.00      dos
# 12                      0.00   normal
# 13                      0.00      r2l
# 14                      0.00      dos
# 15                      0.00      dos
# 16                      0.00   normal
# 17                      0.00    probe
# 18                      0.00   normal
# 19                      0.00   normal
# 20                      0.00      dos
# 21                      0.00      dos
# 22                      0.00   normal
# 23                      0.00   normal
# 24                      0.00      dos
# 25                      0.16   normal
# 26                      0.00      dos
# 27                      0.57   normal
# 28                      0.00   normal
# 29                      0.00   normal
# 30                      0.00    probe
# 31                      0.00      dos
# 32                      0.00   normal
# 33                      1.00    probe
# 34                      0.00   normal
# 35                      0.00   normal
# 36                      0.00   normal
# 37                      0.00      dos
# 38                      0.00   normal
# 39                      0.00      dos
# 40                      0.00      dos
# 41                      0.00      dos
# 42                      0.00   normal
# 43                      0.00   normal
# 44                      0.00   normal
# 45                      0.00      dos
# 46                      0.00      dos
# 47                      0.00   normal
# 48                      0.00      r2l
# 49                      0.00      dos
# 50                      0.00   normal
# 51                      1.00      dos
# 52                      0.00      dos
# 53                      0.00   normal
# 54                      0.00   normal
# 55                      0.00   normal
# 56                      0.00    probe
# 57                      0.00      dos
# 58                      0.00      dos
# 59                      0.00   normal
#
# [60 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'xAttack'],
#       dtype='object')

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (125973, 42)

# %%
df.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'xAttack'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['protocol_type','xAttack']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
df.head(60)
# Out:
#     duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0          0              0       20     2        491          0     0
# 1          0              2       45     2        146          0     0
# 2          0              0       50     4          0          0     0
# 3          0              0       25     2        232       8153     0
# 4          0              0       25     2        199        420     0
# 5          0              0       50     1          0          0     0
# 6          0              0       50     4          0          0     0
# 7          0              0       50     4          0          0     0
# 8          0              0       52     4          0          0     0
# 9          0              0       50     4          0          0     0
# 10         0              0       50     1          0          0     0
# 11         0              0       50     4          0          0     0
# 12         0              0       25     2        287       2251     0
# 13         0              0       20     2        334          0     0
# 14         0              0       37     4          0          0     0
# 15         0              0       39     4          0          0     0
# 16         0              0       25     2        300      13788     0
# 17         0              1       15     2         18          0     0
# 18         0              0       25     2        233        616     0
# 19         0              0       25     2        343       1178     0
# 20         0              0       36     4          0          0     0
# 21         0              0       50     4          0          0     0
# 22         0              0       25     2        253      11905     0
# 23      5607              2       45     2        147        105     0
# 24         0              0       36     4          0          0     0
# 25       507              0       61     2        437      14421     0
# 26         0              0       50     4          0          0     0
# 27         0              0       25     2        227       6588     0
# 28         0              0       25     2        215      10499     0
# 29         0              0       25     2        241       1400     0
# 30         0              1       15     2          8          0     0
# 31         0              0       19     4          0          0     0
# 32         0              0       25     2        303        555     0
# 33         0              0       50     1          0          0     0
# 34         0              2       12     2         45         45     0
# 35         1              2       50     2        105        147     0
# 36         0              2       12     2         43         43     0
# 37         0              0       59     4          0          0     0
# 38         0              0       25     2        324       2302     0
# 39         0              0       67     4          0          0     0
# 40         0              0       20     4          0          0     0
# 41         0              0        3     4          0          0     0
# 42         2              0       55     2       1591        372     0
# 43      9052              2       45     2        146        105     0
# 44         0              0       25     2        290       3006     0
# 45         0              0        8     4          0          0     0
# 46         0              2       50     2         28          0     0
# 47         0              0       25     2        255        861     0
# 48         0              0       20     2        334          0     0
# 49         0              0       20     4          0          0     0
# 50         0              0       25     2        302        498     0
# 51         0              0       50     1          0          0     0
# 52         0              2       50     2         28          0     0
# 53         0              0       25     2        220       1398     0
# 54         0              2       12     2         43         69     0
# 55         0              2       12     2         44        133     0
# 56         0              1       15     2          8          0     0
# 57         0              0       67     4          0          0     0
# 58         0              0       19     4          0          0     0
# 59         0              2       12     2         43         43     0
#
#     wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0                0       0    0  ...                  25
# 1                0       0    0  ...                   1
# 2                0       0    0  ...                  26
# 3                0       0    0  ...                 255
# 4                0       0    0  ...                 255
# 5                0       0    0  ...                  19
# 6                0       0    0  ...                   9
# 7                0       0    0  ...                  15
# 8                0       0    0  ...                  23
# 9                0       0    0  ...                  13
# 10               0       0    0  ...                  12
# 11               0       0    0  ...                  13
# 12               0       0    0  ...                 219
# 13               0       0    0  ...                  20
# 14               0       0    0  ...                   1
# 15               0       0    0  ...                   2
# 16               0       0    0  ...                 255
# 17               0       0    0  ...                  16
# 18               0       0    0  ...                 255
# 19               0       0    0  ...                 255
# 20               0       0    0  ...                  23
# 21               0       0    0  ...                  17
# 22               0       0    0  ...                 255
# 23               0       0    0  ...                   1
# 24               0       0    0  ...                   2
# 25               0       0    0  ...                  25
# 26               0       0    0  ...                  13
# 27               0       0    0  ...                 255
# 28               0       0    0  ...                 255
# 29               0       0    0  ...                 255
# 30               0       0    0  ...                  53
# 31               0       0    0  ...                  59
# 32               0       0    0  ...                 255
# 33               0       0    0  ...                   1
# 34               0       0    0  ...                 250
# 35               0       0    0  ...                   5
# 36               0       0    0  ...                 255
# 37               0       0    0  ...                  17
# 38               0       0    0  ...                 255
# 39               0       0    0  ...                  13
# 40               0       0    0  ...                  63
# 41               0       0    0  ...                   9
# 42               0       0    0  ...                 147
# 43               0       0    0  ...                   2
# 44               0       0    0  ...                 255
# 45               0       0    0  ...                  11
# 46               3       0    0  ...                  80
# 47               0       0    0  ...                 255
# 48               0       0    0  ...                  38
# 49               0       0    0  ...                   5
# 50               0       0    0  ...                 255
# 51               0       0    0  ...                   4
# 52               3       0    0  ...                   2
# 53               0       0    0  ...                 255
# 54               0       0    0  ...                 245
# 55               0       0    0  ...                 212
# 56               0       0    0  ...                  46
# 57               0       0    0  ...                  11
# 58               0       0    0  ...                  59
# 59               0       0    0  ...                 255
#
#     dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                     0.17                    0.03
# 1                     0.00                    0.60
# 2                     0.10                    0.05
# 3                     1.00                    0.00
# 4                     1.00                    0.00
# 5                     0.07                    0.07
# 6                     0.04                    0.05
# 7                     0.06                    0.07
# 8                     0.09                    0.05
# 9                     0.05                    0.06
# 10                    0.05                    0.07
# 11                    0.05                    0.07
# 12                    1.00                    0.00
# 13                    1.00                    0.00
# 14                    0.00                    0.07
# 15                    0.01                    0.06
# 16                    1.00                    0.00
# 17                    1.00                    0.00
# 18                    1.00                    0.00
# 19                    1.00                    0.00
# 20                    0.09                    0.05
# 21                    0.07                    0.06
# 22                    1.00                    0.00
# 23                    0.00                    0.85
# 24                    0.01                    0.06
# 25                    0.10                    0.05
# 26                    0.05                    0.07
# 27                    1.00                    0.00
# 28                    1.00                    0.00
# 29                    1.00                    0.00
# 30                    1.00                    0.00
# 31                    0.23                    0.04
# 32                    1.00                    0.00
# 33                    0.00                    0.31
# 34                    0.98                    0.01
# 35                    0.12                    0.05
# 36                    1.00                    0.00
# 37                    0.07                    0.07
# 38                    1.00                    0.00
# 39                    0.05                    0.07
# 40                    0.25                    0.02
# 41                    0.04                    0.07
# 42                    0.81                    0.02
# 43                    0.01                    0.66
# 44                    1.00                    0.00
# 45                    0.04                    0.07
# 46                    0.31                    0.02
# 47                    1.00                    0.00
# 48                    1.00                    0.00
# 49                    0.02                    0.07
# 50                    1.00                    0.00
# 51                    0.02                    0.08
# 52                    0.01                    0.02
# 53                    1.00                    0.00
# 54                    0.96                    0.01
# 55                    0.88                    0.02
# 56                    1.00                    0.00
# 57                    0.04                    0.07
# 58                    0.23                    0.04
# 59                    1.00                    0.00
#
#     dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                          0
# 40                  1.00                      1.00                  0.00
# 41                  1.00                      1.00                  0.00
# 42                  0.00                      0.00                  0.00
# 43                  0.00                      0.00                  0.00
# 44                  0.00                      0.00                  0.00
# 45                  1.00                      1.00                  0.00
# 46                  0.00                      0.00                  0.00
# 47                  0.00                      0.00                  0.00
# 48                  0.00                      0.00                  0.00
# 49                  1.00                      1.00                  0.00
# 50                  0.00                      0.00                  0.00
# 51                  0.00                      0.00                  1.00
# 52                  0.00                      0.00                  0.77
# 53                  0.00                      0.00                  0.00
# 54                  0.00                      0.00                  0.00
# 55                  0.00                      0.00                  0.08
# 56                  0.00                      0.00                  0.00
# 57                  1.00                      1.00                  0.00
# 58                  1.00                      1.00                  0.00
# 59                  0.00                      0.00                  0.00
#
#     dst_host_srv_rerror_rate  xAttack
# 0                       0.00        1
# 1                       0.00        1
# 2                       0.00        0
# 3                       0.01        1
# 4                       0.00        1
# 5                       1.00        0
# 6                       0.00        0
# 7                       0.00        0
# 8                       0.00        0
# 9                       0.00        0
# 10                      1.00        0
# 11                      0.00        0
# 12                      0.00        1
# 13                      0.00        3
# 14                      0.00        0
# 15                      0.00        0
# 16                      0.00        1
# 17                      0.00        2
# 18                      0.00        1
# 19                      0.00        1
# 20                      0.00        0
# 21                      0.00        0
# 22                      0.00        1
# 23                      0.00        1
# 24                      0.00        0
# 25                      0.16        1
# 26                      0.00        0
# 27                      0.57        1
# 28                      0.00        1
# 29                      0.00        1
# 30                      0.00        2
# 31                      0.00        0
# 32                      0.00        1
# 33                      1.00        2
# 34                      0.00        1
# 35                      0.00        1
# 36                      0.00        1
# 37                      0.00        0
# 38                      0.00        1
# 39                      0.00        0
# 40                      0.00        0
# 41                      0.00        0
# 42                      0.00        1
# 43                      0.00        1
# 44                      0.00        1
# 45                      0.00        0
# 46                      0.00        0
# 47                      0.00        1
# 48                      0.00        3
# 49                      0.00        0
# 50                      0.00        1
# 51                      1.00        0
# 52                      0.00        0
# 53                      0.00        1
# 54                      0.00        1
# 55                      0.00        1
# 56                      0.00        2
# 57                      0.00        0
# 58                      0.00        0
# 59                      0.00        1
#
# [60 rows x 42 columns]

# %%
x1 = df.drop(labels='xAttack', axis=1)
y1 = df.loc[:,'xAttack']

# %%
#import imblearn
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

ros =RandomOverSampler(random_state=42)
x,y=ros.fit_resample(x1,y1)
print("OUR DATASET COUNT         : ", Counter(y1))
print("OVER SAMPLING DATA COUNT  : ", Counter(y))
# Out:
# OUR DATASET COUNT         :  Counter({1: 67343, 0: 45927, 2: 11656, 3: 995, 4: 52})
# OVER SAMPLING DATA COUNT  :  Counter({1: 67343, 0: 67343, 3: 67343, 2: 67343, 4: 67343})

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42, stratify=y)
print("NUMBER OF TRAIN DATASET    : ", len(x_train))
print("NUMBER OF TEST DATASET      : ", len(x_test))
print("TOTAL NUMBER OF DATASET    : ", len(x_train)+len(x_test))
# Out:
# NUMBER OF TRAIN DATASET    :  269372
# NUMBER OF TEST DATASET      :  67343
# TOTAL NUMBER OF DATASET    :  336715

# %%
print("NUMBER OF TRAIN DATASET    : ", len(y_train))
print("NUMBER OF TEST DATASET      : ", len(y_test))
print("TOTAL NUMBER OF DATASET    : ", len(y_train)+len(y_test))
# Out:
# NUMBER OF TRAIN DATASET    :  269372
# NUMBER OF TEST DATASET      :  67343
# TOTAL NUMBER OF DATASET    :  336715

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predicted = rf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
print('THE CONFUSION MATRIX SCORE OF RandomForestClassifier:\n\n\n',cm)
# Out:
# THE CONFUSION MATRIX SCORE OF RandomForestClassifier:
#
#
#  [[13469     0     0     0     0]
#  [    1 13462     2     1     2]
#  [    0     0 13469     0     0]
#  [    0     0     0 13469     0]
#  [    0     0     0     0 13468]]

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(y_test,predicted)
print("THE ACCURACY SCORE OF RandomForestClassifier IS :",a*100)
# Out:
# THE ACCURACY SCORE OF RandomForestClassifier IS : 99.9910903880136

# %%
from sklearn.metrics import hamming_loss
hl = hamming_loss(y_test,predicted)
print("THE HAMMING LOSS OF RandomForestClassifier IS :",hl*100)
# Out:
# THE HAMMING LOSS OF RandomForestClassifier IS : 0.008909611986397992

# %%
from sklearn.metrics import classification_report
P = classification_report(y_test,predicted)
print("THE CLASSIFICATION REPORT OF RandomForestClassifier IS :\n\n",P)
# Out:
# THE CLASSIFICATION REPORT OF RandomForestClassifier IS :
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13469
#            1       1.00      1.00      1.00     13468
#            2       1.00      1.00      1.00     13469
#            3       1.00      1.00      1.00     13469
#            4       1.00      1.00      1.00     13468
#
#     accuracy                           1.00     67343
#    macro avg       1.00      1.00      1.00     67343
# weighted avg       1.00      1.00      1.00     67343

# %%
cm=confusion_matrix(y_test, predicted)
print('THE CONFUSION MATRIX SCORE OF RandomForestClassifier:\n\n')
print(cm)
print("\n\nDISPLAY CONFUSION MATRIX : \n\n")
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, predicted, labels=rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf.classes_)
disp.plot()
plt.show()
# Out:
# THE CONFUSION MATRIX SCORE OF RandomForestClassifier:
#
#
# [[13469     0     0     0     0]
#  [    1 13462     2     1     2]
#  [    0     0 13469     0     0]
#  [    0     0     0 13469     0]
#  [    0     0     0     0 13468]]
#
#
# DISPLAY CONFUSION MATRIX :

# %%
def graph():
    import matplotlib.pyplot as plt
    data=[a]
    alg="EXTRA TREE CLASSIFIER"
    plt.figure(figsize=(5,5))
    b=plt.bar(alg,data,color=("ORANGE"))
    plt.title("THE ACCURACY SCORE OF RandomForestClassifier IS\n\n\n")
    plt.legend(b,data,fontsize=9)
graph()

# %%
import joblib
joblib.dump(RFC, 'INTRUSION.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5064\2540338715.py in <module>
#       1 import joblib
# ----> 2 joblib.dump(RFC, 'INTRUSION.pkl')
#
# NameError: name 'RFC' is not defined
